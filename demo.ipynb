# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np

# Generate synthetic data
num_rows = 200
num_cols = 56

# Generate device_id
device_ids = np.arange(num_rows) + 1

# Generate current_op_score
current_op_scores = np.random.randint(0, 101, size=num_rows)

# Generate historic_op_scores
historic_op_scores = np.random.randint(0, 101, size=(num_rows, num_cols - 2))

# Create dataframe
data = np.column_stack((device_ids, current_op_scores, historic_op_scores))
columns = ['device_id', 'current_op_score'] + [f'past_time_{i}' for i in range(1, num_cols - 1)]
df = pd.DataFrame(data, columns=columns)

# Save to CSV
df.to_csv('data.csv', index=False)

# %%
df
# Out:
#      device_id  current_op_score  past_time_1  past_time_2  past_time_3  \
# 0            1                16            5           99           38
# 1            2                91           26           35           85
# 2            3                49           77           40           69
# 3            4                78           17           76           43
# 4            5                73           90           20           93
# ..         ...               ...          ...          ...          ...
# 195        196                43           54           14           14
# 196        197                69           61           43           47
# 197        198               100           56           33            6
# 198        199                68            4           99           81
# 199        200                56           55           24           36
#
#      past_time_4  past_time_5  past_time_6  past_time_7  past_time_8  ...  \
# ...
